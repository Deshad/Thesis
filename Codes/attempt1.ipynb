# %%
import cv2
import os
from collections import defaultdict
import glob
from torch.utils.data import Dataset
import torchvision.transforms as T
from torch.utils.data import DataLoader

# %%
#structure of the dataset
import os

def print_tree(startpath, indent=''):
    for item in os.listdir(startpath):
        path = os.path.join(startpath, item)
        print(indent + "|-- " + item)
        if os.path.isdir(path):
            print_tree(path, indent + "    ")

print_tree("C:/Users/2955352g/Desktop/pig_data_edinburgh")
# Out:
# |-- annotated
#     |-- 2019_11_05
#         |-- 000002
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#         |-- 000009
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_11_11
#         |-- 000016
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#         |-- 000028
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#         |-- 000036
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_11_15
#         |-- 000033
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_11_22
#         |-- 000010
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_11_28
#         |-- 000113
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_12_02
#         |-- 000005
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#         |-- 000208
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_12_10
#         |-- 000060
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
#         |-- 000078
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- output.json
#             |-- rot.npy
#             |-- times.txt
# |-- unannotated
#     |-- 2019_11_11
#         |-- 000000
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000001
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000002
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000003
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000004
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000005
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000006
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000007
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000008
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000009
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000010
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000011
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000012
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000013
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000014
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000015
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000017
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000018
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000019
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000020
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000021
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000022
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000023
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000024
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000025
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000026
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000027
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000029
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000030
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000031
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000032
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000033
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000034
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000035
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000037
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000038
#             |-- background.png
#             |-- background_depth.png
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_11_22
#         |-- 000000
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000001
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000002
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000003
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000004
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000005
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000006
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000007
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000008
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000009
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000011
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000012
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000013
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000014
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000015
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000016
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000017
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000018
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000019
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000020
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000021
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000022
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000023
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000024
#             |-- background.png
#             |-- background_depth.png
#             |-- color.mp4
#             |-- depth.mp4
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#         |-- 000025
#             |-- background.png
#             |-- background_depth.png
#             |-- depth_scale.npy
#             |-- inverse_intrinsic.npy
#             |-- mask.png
#             |-- rot.npy
#             |-- times.txt
#     |-- 2019_12_02
#         |-- PIGS021219a
#             |-- 000545
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000546
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000547
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000548
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000549
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000550
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000551
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000552
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000553
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000554
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000555
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000556
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000557
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000558
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000559
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000560
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000561
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000562
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000563
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000564
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000565
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000566
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000567
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000568
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000569
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000570
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000571
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000572
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000573
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000574
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000575
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000576
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000577
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000578
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000579
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000580
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000581
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000582
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000583
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000584
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt
#             |-- 000585
#                 |-- background.png
#                 |-- background_depth.png
#                 |-- color.mp4
#                 |-- depth.mp4
#                 |-- depth_scale.npy
#                 |-- inverse_intrinsic.npy
#                 |-- mask.png
#                 |-- rot.npy
#                 |-- times.txt

# %%
#
def load_annotations(json_path):
    with open(json_path) as f:
        data = json.load(f)
    
    # Organize by frame number
    annotations = defaultdict(list)
    for obj in data['objects']:
        for frame in obj['frames']:
            frame_num = frame['frameNumber']
            annotations[frame_num].append({
                'bbox': [frame['bbox']['x'], frame['bbox']['y'], 
                         frame['bbox']['width'], frame['bbox']['height']],
                'behavior': frame['behaviour'],
                'visible': frame['visible']
            })
    return annotations

# %%
#extarcting frames and aligning them
def extract_frames(video_path, output_dir, annotations=None, fps=5):
    os.makedirs(output_dir, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_rate = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(frame_rate / fps)
    frame_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
            
        if frame_count % frame_interval == 0:
            # Save frame
            frame_file = f"frame_{frame_count:04d}.jpg"
            cv2.imwrite(os.path.join(output_dir, frame_file), frame)
            
            # Save corresponding annotations if available
            if annotations and frame_count in annotations:
                with open(os.path.join(output_dir, f"frame_{frame_count:04d}.json"), 'w') as f:
                    json.dump(annotations[frame_count], f)
                    
        frame_count += 1
    cap.release()

# %%
base_dir = "pig_data_edinburgh/annotated"

for date_dir in glob.glob(f"{base_dir}/*"):
    for clip_dir in glob.glob(f"{date_dir}/*"):
        # Load annotations
        annotations = load_annotations(f"{clip_dir}/output.json")
        
        # Extract frames
        extract_frames(
            video_path=f"{clip_dir}/color.mp4",
            output_dir=f"processed/{os.path.basename(date_dir)}/{os.path.basename(clip_dir)}",
            annotations=annotations
        )

# %%
#converting to pytorch dataset
class PigBehaviorDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform or T.Compose([
            T.Resize(256),
            T.ToTensor(),
            T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
        
        # Collect all annotated frames
        self.samples = []
        for date_dir in glob.glob(f"{root_dir}/*"):
            for clip_dir in glob.glob(f"{date_dir}/*"):
                for frame in glob.glob(f"{clip_dir}/frame_*.jpg"):
                    json_file = frame.replace('.jpg', '.json')
                    if os.path.exists(json_file):
                        self.samples.append((frame, json_file))
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, ann_path = self.samples[idx]
        
        # Load image
        img = Image.open(img_path).convert('RGB')
        
        # Load annotations
        with open(ann_path) as f:
            annotations = json.load(f)
        
        # Convert to tensors
        boxes = []
        behaviors = []
        for ann in annotations:
            boxes.append(ann['bbox'])
            behaviors.append(ann['behavior'])
        
        target = {
            'boxes': torch.as_tensor(boxes, dtype=torch.float32),
            'labels': torch.as_tensor([behavior_to_idx[b] for b in behaviors], dtype=torch.int64)
        }
        
        if self.transform:
            img = self.transform(img)
            
        return img, target

# %%
#behaviour classification
# Behavior to index mapping
behavior_to_idx = {
    'lying': 0,
    'standing': 1,
    'walking': 2,
    'investigating': 3,
    'drinking': 4
}

# Model setup (example using Faster R-CNN)
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# Load a pretrained backbone
backbone = torchvision.models.mobilenet_v2(pretrained=True).features
backbone.out_channels = 1280

# Define anchor generator
anchor_generator = AnchorGenerator(
    sizes=((32, 64, 128, 256, 512),),
    aspect_ratios=((0.5, 1.0, 2.0),)
)

# Put it all together
model = FasterRCNN(
    backbone,
    num_classes=len(behavior_to_idx)+1,  # +1 for background
    rpn_anchor_generator=anchor_generator
)

# %%
#training
dataset = PigBehaviorDataset("processed")
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: x)

optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9)

for epoch in range(10):
    for images, targets in dataloader:
        # Forward pass
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        
        # Backward pass
        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 #training
#       2 dataset = PigBehaviorDataset("processed")
# ----> 3 dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=lambda x: x)
#       5 optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9)
#       7 for epoch in range(10):
#
# File c:\Users\2955352g\.conda\envs\tf_env\Lib\site-packages\torch\utils\data\dataloader.py:376, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     374 else:  # map-style
#     375     if shuffle:
# --> 376         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     377     else:
#     378         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File c:\Users\2955352g\.conda\envs\tf_env\Lib\site-packages\torch\utils\data\sampler.py:164, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     159     raise TypeError(
#     160         f"replacement should be a boolean value, but got replacement={self.replacement}"
#     161     )
#     163 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 164     raise ValueError(
#     165         f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     166     )
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0
